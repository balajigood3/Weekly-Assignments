# %%
#importing the Libraies
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Reading the Dataset
dataset = pd.read_csv('insurance_pre.csv')

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset,drop_first=True)

# %%
indep=dataset[[
    'age', 
    'bmi', 
    'children',
    'sex_male', 
    'smoker_yes']]
dep=dataset['charges']

# %%
#split into training set and test
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(indep, dep, test_size = 1/3, random_state = 0)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeRegressor

param_grid = {
    'criterion': ['squared_error', 'absolute_error', 'friedman_mse'],
    'max_features': [None, 'sqrt', 'log2'],
    'splitter': ['best', 'random']
}

grid = GridSearchCV(
    DecisionTreeRegressor(random_state=42),
    param_grid,
    refit=True,
    verbose=3,
    n_jobs=-1
)
grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# GridSearchCV(estimator=DecisionTreeRegressor(random_state=42), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'absolute_error',
#                                        'friedman_mse'],
#                          'max_features': [None, 'sqrt', 'log2'],
#                          'splitter': ['best', 'random']},
#              verbose=3)

# %%
# Print best parameters after tuning
print("Best Parameters:", grid.best_params_)

grid_predictions = grid.predict(X_test)

from sklearn.metrics import r2_score
r_score = r2_score(y_test, grid_predictions)

print("The R2 score value for best parameters {}: {}".format(
    grid.best_params_, r_score
))

re = grid.cv_results_
print(re)
# Out:
# Best Parameters: {'criterion': 'absolute_error', 'max_features': None, 'splitter': 'random'}
# The R2 score value for best parameters {'criterion': 'absolute_error', 'max_features': None, 'splitter': 'random'}: 0.7673597289014886
# {'mean_fit_time': array([0.00814652, 0.00629821, 0.00545611, 0.00407038, 0.00592432,
#        0.00442901, 0.02052274, 0.01971917, 0.0148973 , 0.01312332,
#        0.01331882, 0.01293445, 0.00841584, 0.00603952, 0.00570383,
#        0.004458  , 0.00714951, 0.00324368]), 'std_fit_time': array([0.0010864 , 0.00075923, 0.00108755, 0.00023557, 0.00117577,
#        0.00029198, 0.00248255, 0.00284102, 0.00279503, 0.00215331,
#        0.00110035, 0.00090174, 0.003071  , 0.00207872, 0.00146337,
#        0.00060171, 0.00308095, 0.00048098]), 'mean_score_time': array([0.00192175, 0.00186491, 0.00154471, 0.00168476, 0.00176291,
#        0.00162301, 0.00158491, 0.00186219, 0.00169263, 0.0016118 ,
#        0.00161204, 0.00284033, 0.00160923, 0.00178032, 0.00216432,
# ...

# %%
re = grid.cv_results_
table = pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.008147      0.001086         0.001922        0.000223
# 1        0.006298      0.000759         0.001865        0.000199
# 2        0.005456      0.001088         0.001545        0.000061
# 3        0.004070      0.000236         0.001685        0.000203
# 4        0.005924      0.001176         0.001763        0.000279
# 5        0.004429      0.000292         0.001623        0.000084
# 6        0.020523      0.002483         0.001585        0.000110
# 7        0.019719      0.002841         0.001862        0.000355
# 8        0.014897      0.002795         0.001693        0.000267
# 9        0.013123      0.002153         0.001612        0.000109
# 10       0.013319      0.001100         0.001612        0.000192
# 11       0.012934      0.000902         0.002840        0.002695
# 12       0.008416      0.003071         0.001609        0.000081
# ...

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker Yes 0 or 1:"))

print("age_input:", age_input)
print("bmi_input:", bmi_input) 
print("children_input:", children_input) 
print("sex_male_input:", sex_male_input)
print("smoker_yes_input:", smoker_yes_input)
# Out:
# age_input: 61.0
# bmi_input: 29.07
# children_input: 0.0
# sex_male_input: 1
# smoker_yes_input: 1

# %%
grid = GridSearchCV

Future_Prediction = grid.predict([[age_input, bmi_input, children_input, sex_male_input, smoker_yes_input]])

#change the paramter,play with it.
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 grid = GridSearchCV
#       3 Future_Prediction = grid.predict([[age_input, bmi_input, children_input, sex_male_input, smoker_yes_input]])
#       5 #change the paramter,play with it.
#
# NameError: name 'GridSearchCV' is not defined
