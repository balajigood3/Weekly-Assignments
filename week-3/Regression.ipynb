# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, mean_squared_error
import matplotlib.pyplot as plt
from sklearn.ensemble import GradientBoostingClassifier, AdaBoostClassifier, BaggingClassifier
from sklearn.tree import DecisionTreeClassifier

# %%
# Regression Model using Linear Regression in Machine Learning
#.1.Linear Regression
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(Xr_train, yr_train)

pred = model.predict(Xr_test)
print("MSE:", mean_squared_error(yr_test, pred))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 7
#       4 from sklearn.linear_model import LinearRegression
#       6 model = LinearRegression()
# ----> 7 model.fit(Xr_train, yr_train)
#       9 pred = model.predict(Xr_test)
#      10 print("MSE:", mean_squared_error(yr_test, pred))
#
# NameError: name 'Xr_train' is not defined

# %%
#2. Ridge Regression
from sklearn.linear_model import Ridge

model = Ridge(alpha=1.0)
model.fit(Xr_train, yr_train)

pred = model.predict(Xr_test)
print("MSE:", mean_squared_error(yr_test, pred))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 5
#       2 from sklearn.linear_model import Ridge
#       4 model = Ridge(alpha=1.0)
# ----> 5 model.fit(Xr_train, yr_train)
#       7 pred = model.predict(Xr_test)
#       8 print("MSE:", mean_squared_error(yr_test, pred))
#
# NameError: name 'Xr_train' is not defined

# %%
#3. Lasso Regression
from sklearn.linear_model import Lasso

model = Lasso(alpha=0.1)
model.fit(Xr_train, yr_train)

pred = model.predict(Xr_test)
print("MSE:", mean_squared_error(yr_test, pred))

# %%
#4. Elastic Net Regression
from sklearn.linear_model import ElasticNet
model = ElasticNet(alpha=0.1, l1_ratio=0.5)
model.fit(Xr_train, yr_train)
pred = model.predict(Xr_test)
print("MSE:", mean_squared_error(yr_test, pred))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 4
#       2 from sklearn.linear_model import ElasticNet
#       3 model = ElasticNet(alpha=0.1, l1_ratio=0.5)
# ----> 4 model.fit(Xr_train, yr_train)
#       5 pred = model.predict(Xr_test)
#       6 print("MSE:", mean_squared_error(yr_test, pred))
#
# NameError: name 'Xr_train' is not defined

# %%
#5. Decision Tree Regression
from sklearn.tree import DecisionTreeRegressor

model = DecisionTreeRegressor()
model.fit(Xr_train, yr_train)

pred = model.predict(Xr_test)
print("MSE:", mean_squared_error(yr_test, pred))

# %%
#6. Random Forest Regression
from sklearn.ensemble import RandomForestRegressor

model = RandomForestRegressor(n_estimators=100)
model.fit(Xr_train, yr_train)

pred = model.predict(Xr_test)
print("MSE:", mean_squared_error(yr_test, pred))

# %%
#7. Support Vector Regression
from sklearn.svm import SVR

model = SVR(kernel='rbf')
model.fit(Xr_train, yr_train)

pred = model.predict(Xr_test)
print("MSE:", mean_squared_error(yr_test, pred))
