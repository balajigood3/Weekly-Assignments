# %%
#1.Module Not Found Error
import numpy as np
import tensorflow as tf  # Added missing import

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# Generate dummy data
X_train = np.random.rand(100, 10)
y_train = np.random.randint(0, 2, size=(100,))

# Define the model
model = Sequential([
    Dense(32, activation='relu', input_shape=(10,)),
    Dense(1, activation='sigmoid')
])

# Compile model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Train model
model.fit(X_train, y_train, epochs=5)
# Out:
# Epoch 1/5
# 4/4 [==============================] - 4s 16ms/step - loss: 0.7250 - accuracy: 0.4900
# Epoch 2/5
# 4/4 [==============================] - 0s 34ms/step - loss: 0.7152 - accuracy: 0.5000
# Epoch 3/5
# 4/4 [==============================] - 0s 16ms/step - loss: 0.7094 - accuracy: 0.5000
# Epoch 4/5
# 4/4 [==============================] - 0s 28ms/step - loss: 0.7046 - accuracy: 0.5000
# Epoch 5/5
# 4/4 [==============================] - 0s 27ms/step - loss: 0.7020 - accuracy: 0.5100

# %%
#2.Mismatched Input Shape in CNN**import numpy as np
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, Flatten, Dense

# Generate dummy image data
X_train = np.random.rand(100, 32, 32, 3)  # Added channel dimension (RGB)
y_train = np.random.randint(0, 10, size=(100,))

# Define CNN Model
model = Sequential([
    Conv2D(32, (3,3), activation='relu', input_shape=(32,32,3)),
    Flatten(),
    Dense(10, activation='softmax')
])

model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

model.fit(X_train, y_train, epochs=5)
# Out:
# Epoch 1/5
# 4/4 [==============================] - 1s 9ms/step - loss: 2.9867 - accuracy: 0.1400
# Epoch 2/5
# 4/4 [==============================] - 0s 10ms/step - loss: 2.4029 - accuracy: 0.2000
# Epoch 3/5
# 4/4 [==============================] - 0s 11ms/step - loss: 1.7829 - accuracy: 0.2500
# Epoch 4/5
# 4/4 [==============================] - 0s 11ms/step - loss: 1.3964 - accuracy: 0.4800
# Epoch 5/5
# 4/4 [==============================] - 0s 11ms/step - loss: 0.8838 - accuracy: 0.9200

# %%
## **3.Undefined Variable Error**
import numpy as np
import tensorflow as tf
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.layers import AveragePooling2D, Flatten, Dense, Input
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import Model

# Load pre-trained MobileNetV2 model
baseModel = MobileNetV2(weights="imagenet", include_top=False, input_tensor=Input(shape=(224, 224, 3)))

# Add custom layers
headModel = baseModel.output
headModel = Flatten(name="flatten")(headModel)
headModel = Dense(128, activation="relu")(headModel)
headModel = Dense(1, activation="sigmoid")(headModel)
model = Model(inputs=baseModel.input, outputs=headModel)
# Define missing variables
INIT_LR = 0.0001
EPOCHS = 20
opt = tf.keras.optimizers.Adam(learning_rate=INIT_LR)
# Alternative: Use Learning Rate Scheduler if decay is needed
lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate=INIT_LR,
    decay_steps=1000,  # Adjust this based on dataset size
    decay_rate=0.96,  # Reduce LR by 4% every 1000 steps
    staircase=True
)

# Compile model
opt = Adam(learning_rate=INIT_LR)  # Error: Undefined variables
model.compile(loss="binary_crossentropy", optimizer=opt, metrics=["accuracy"])
print("Model compiled successfully")
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# Model compiled successfully

# %%
from PIL import Image

image_path = r"D:\Balaji-VP\assignment\Week-11 assignment\Images_to_use\flower.jpg"

img = Image.open(image_path)

# %%
 #4.FileNotFoundError                         
from PIL import Image
from tensorflow.keras.preprocessing import image
import numpy as np

# 1. Provide the correct path (use raw string r"" to avoid backslash issues)
image_path = r"D:\Balaji-VP\assignment\Week-11 assignment\Images_to_use\flower.jpg"

# 2. Open the image
img = Image.open(image_path)

# 3. Resize the image (tuple)
img = img.resize((224, 224))

# 4. Convert to array
img_array = image.img_to_array(img)

# 5. Expand dimensions for model input (batch size 1)
img_array = np.expand_dims(img_array, axis=0)

# 6. (Optional) Normalize if your model expects it
img_array /= 255.0

print("Image shape ready for model:", img_array.shape)
# Out:
# Image shape ready for model: (1, 224, 224, 3)
