# %%
# Batch 2 - Coding Solution
# 1. Object Detection with YOLOv5 (Using Pretrained Weights)
# Problem: Detect objects using pre-trained YOLOv5 model.
from ultralytics import YOLO

# Load your trained model from Ultralytics Platform
model = YOLO("balaji1989/relaxed-sphinx/yolov5su")

# Run inference on an image
results = model("path/to/image.jpg")

# Process results
for result in results:
    boxes = result.boxes  # Bounding boxes
    result.show()  # Display annotated image
# Underfitting and false negatives observed. Model needs further training on custom dataset.
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 10
#       7 model = YOLO("balaji1989/relaxed-sphinx/yolov5su")
#       9 # Run inference on an image
# ---> 10 results = model("balaji1989/relaxed-sphinx/yolov5su.jpg")
#      12 # Process results
#      13 for result in results:
#
# File c:\Users\BALAJI MURUGAN\AppData\Local\Programs\Python\Python39\lib\site-packages\ultralytics\engine\model.py:177, in Model.__call__(self, source, stream, **kwargs)
#     149 def __call__(
#     150     self,
#     151     source: str | Path | int | Image.Image | list | tuple | np.ndarray | torch.Tensor = None,
#     152     stream: bool = False,
#     153     **kwargs: Any,
#     154 ) -> list:
#     155     """Alias for the predict method, enabling the model instance to be callable for predictions.
#     156
#     157     This method simplifies the process of making predictions by allowing the model instance to be called directly
#    (...)
#     175         ...     print(f"Detected {len(r)} objects in image")
#     176     """
# --> 177     return self.predict(source, stream, **kwargs)
#
# File c:\Users\BALAJI MURUGAN\AppData\Local\Programs\Python\Python39\lib\site-packages\ultralytics\engine\model.py:536, in Model.predict(self, source, stream, predictor, **kwargs)
#     534 if prompts and hasattr(self.predictor, "set_prompts"):  # for SAM-type models
#     535     self.predictor.set_prompts(prompts)
# --> 536 return self.predictor.predict_cli(source=source) if is_cli else self.predictor(source=source, stream=stream)
#
# File c:\Users\BALAJI MURUGAN\AppData\Local\Programs\Python\Python39\lib\site-packages\ultralytics\engine\predictor.py:225, in BasePredictor.__call__(self, source, model, stream, *args, **kwargs)
#     223     return self.stream_inference(source, model, *args, **kwargs)
#     224 else:
# --> 225     return list(self.stream_inference(source, model, *args, **kwargs))
#
# File c:\Users\BALAJI MURUGAN\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\utils\_contextlib.py:38, in _wrap_generator.<locals>.generator_context(*args, **kwargs)
#      35 try:
#      36     # Issuing `None` to a generator fires it up
#      37     with ctx_factory():
# ---> 38         response = gen.send(None)
#      40     while True:
#      41         try:
#      42             # Forward the response to our caller and get its next request
#
# File c:\Users\BALAJI MURUGAN\AppData\Local\Programs\Python\Python39\lib\site-packages\ultralytics\engine\predictor.py:299, in BasePredictor.stream_inference(self, source, model, *args, **kwargs)
#     295     self.setup_model(model)
#     297 with self._lock:  # for thread-safe inference
#     298     # Setup source every time predict is called
# --> 299     self.setup_source(source if source is not None else self.args.source)
#     301     # Check if save_dir/ label file exists
#     302     if self.args.save or self.args.save_txt:
#
# File c:\Users\BALAJI MURUGAN\AppData\Local\Programs\Python\Python39\lib\site-packages\ultralytics\engine\predictor.py:256, in BasePredictor.setup_source(self, source, stride)
#     248 """Set up source and inference mode.
#     249
#     250 Args:
#    (...)
#     253     stride (int, optional): Model stride for image size checking.
#     254 """
#     255 self.imgsz = check_imgsz(self.args.imgsz, stride=stride or self.model.stride, min_dim=2)  # check image size
# --> 256 self.dataset = load_inference_source(
#     257     source=source,
#     258     batch=self.args.batch,
#     259     vid_stride=self.args.vid_stride,
#     260     buffer=self.args.stream_buffer,
#     261     channels=getattr(self.model, "ch", 3),
#     262 )
#     263 self.source_type = self.dataset.source_type
#     264 if (
#     265     self.source_type.stream
#     266     or self.source_type.screenshot
#     267     or len(self.dataset) > 1000  # many images
#     268     or any(getattr(self.dataset, "video_flag", [False]))
#     269 ):  # long sequence
#
# File c:\Users\BALAJI MURUGAN\AppData\Local\Programs\Python\Python39\lib\site-packages\ultralytics\data\build.py:432, in load_inference_source(source, batch, vid_stride, buffer, channels)
#     430     dataset = LoadPilAndNumpy(source, channels=channels)
#     431 else:
# --> 432     dataset = LoadImagesAndVideos(source, batch=batch, vid_stride=vid_stride, channels=channels)
#     434 # Attach source types to the dataset
#     435 setattr(dataset, "source_type", source_type)
#
# File c:\Users\BALAJI MURUGAN\AppData\Local\Programs\Python\Python39\lib\site-packages\ultralytics\data\loaders.py:369, in LoadImagesAndVideos.__init__(self, path, batch, vid_stride, channels)
#     367         files.append(str((parent / p).absolute()))  # files (relative to *.txt file parent)
#     368     else:
# --> 369         raise FileNotFoundError(f"{p} does not exist")
#     371 # Define files as images or videos
#     372 images, videos = [], []
#
# FileNotFoundError: balaji1989/relaxed-sphinx/yolov5su.jpg does not exist

# %%
# 2.Preprocessing Image for ResNet Input
# Problem: Write a function to preprocess image for pretrained ResNet.from torchvision import transforms

from PIL import Image

def preprocess_image(img_path):
    image = Image.open(img_path).convert("RGB")
    transform = transforms.Compose([
        transforms.Resize((224, 224)),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406],
                             [0.229, 0.224, 0.225])
    ])
    return transform(image).unsqueeze(0)

# %%
# 3. CNN for CIFAR-10 Classification
# Problem: Build a CNN model to classify CIFAR-10 images.
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.datasets import cifar10

# Load data
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

# Normalize images
x_train = x_train.astype("float32") / 255.0
x_test = x_test.astype("float32") / 255.0

# Build CNN model
model = Sequential([
    Conv2D(32, (3,3), activation='relu', input_shape=(32,32,3)),
    MaxPooling2D(2,2),

    Conv2D(64, (3,3), activation='relu'),
    MaxPooling2D(2,2),

    Flatten(),
    Dense(128, activation='relu'),
    Dropout(0.3),
    Dense(10, activation='softmax')
])

# Compile model
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# Train model
model.fit(
    x_train,
    y_train,
    epochs=20,
    batch_size=32,
    validation_data=(x_test, y_test)
)
# Out:
# Epoch 1/20
# 1563/1563 [==============================] - 54s 34ms/step - loss: 1.5501 - accuracy: 0.4365 - val_loss: 1.2360 - val_accuracy: 0.5622
# Epoch 2/20
# 1563/1563 [==============================] - 55s 35ms/step - loss: 1.2089 - accuracy: 0.5733 - val_loss: 1.0951 - val_accuracy: 0.6109
# Epoch 3/20
# 1563/1563 [==============================] - 46s 29ms/step - loss: 1.0784 - accuracy: 0.6170 - val_loss: 0.9745 - val_accuracy: 0.6611
# Epoch 4/20
# 1563/1563 [==============================] - 51s 33ms/step - loss: 0.9928 - accuracy: 0.6510 - val_loss: 0.9433 - val_accuracy: 0.6774
# Epoch 5/20
# 1563/1563 [==============================] - 40s 25ms/step - loss: 0.9204 - accuracy: 0.6771 - val_loss: 0.8885 - val_accuracy: 0.6897
# Epoch 6/20
# 1563/1563 [==============================] - 44s 28ms/step - loss: 0.8645 - accuracy: 0.6967 - val_loss: 0.8849 - val_accuracy: 0.6976
# Epoch 7/20
# 1563/1563 [==============================] - 43s 27ms/step - loss: 0.8159 - accuracy: 0.7131 - val_loss: 0.8933 - val_accuracy: 0.6909
# Epoch 8/20
# 1563/1563 [==============================] - 47s 30ms/step - loss: 0.7752 - accuracy: 0.7266 - val_loss: 0.8693 - val_accuracy: 0.7002
# Epoch 9/20
# 1563/1563 [==============================] - 45s 29ms/step - loss: 0.7354 - accuracy: 0.7413 - val_loss: 0.8695 - val_accuracy: 0.6996
# Epoch 10/20
# 1563/1563 [==============================] - 51s 33ms/step - loss: 0.6969 - accuracy: 0.7538 - val_loss: 0.8599 - val_accuracy: 0.7083
# Epoch 11/20
# 1563/1563 [==============================] - 48s 31ms/step - loss: 0.6631 - accuracy: 0.7637 - val_loss: 0.8694 - val_accuracy: 0.7061
# Epoch 12/20
# 1563/1563 [==============================] - 50s 32ms/step - loss: 0.6340 - accuracy: 0.7743 - val_loss: 0.8706 - val_accuracy: 0.7075
# Epoch 13/20
# 1563/1563 [==============================] - 57s 37ms/step - loss: 0.6085 - accuracy: 0.7845 - val_loss: 0.8831 - val_accuracy: 0.7150
# Epoch 14/20
# 1563/1563 [==============================] - 53s 34ms/step - loss: 0.5822 - accuracy: 0.7916 - val_loss: 0.9347 - val_accuracy: 0.7075
# Epoch 15/20
# 1563/1563 [==============================] - 38s 24ms/step - loss: 0.5575 - accuracy: 0.8005 - val_loss: 0.9235 - val_accuracy: 0.7047
# Epoch 16/20
# 1563/1563 [==============================] - 38s 24ms/step - loss: 0.5368 - accuracy: 0.8056 - val_loss: 0.9417 - val_accuracy: 0.7047
# Epoch 17/20
# 1563/1563 [==============================] - 44s 28ms/step - loss: 0.5219 - accuracy: 0.8107 - val_loss: 0.9544 - val_accuracy: 0.7140
# Epoch 18/20
# 1563/1563 [==============================] - 51s 33ms/step - loss: 0.5035 - accuracy: 0.8176 - val_loss: 0.9806 - val_accuracy: 0.7112
# Epoch 19/20
# 1563/1563 [==============================] - 53s 34ms/step - loss: 0.4809 - accuracy: 0.8254 - val_loss: 0.9836 - val_accuracy: 0.7083
# Epoch 20/20
# 1563/1563 [==============================] - 51s 33ms/step - loss: 0.4663 - accuracy: 0.8305 - val_loss: 1.0078 - val_accuracy: 0.7023

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense

# Simple CNN model
model = Sequential([
    Conv2D(32, (3,3), activation='relu', input_shape=(128,128,3)),
    MaxPooling2D(2,2),

    Conv2D(64, (3,3), activation='relu'),
    MaxPooling2D(2,2),

    Flatten(),
    Dense(128, activation='relu'),
    Dense(2, activation='softmax')  # Mask / No Mask
])

model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# SAVE MODEL
model.save("mask_detector.h5")

print("✅ mask_detector.h5 file created successfully")
# Out:
# ✅ mask_detector.h5 file created successfully

# %%
# 5. Scenario: Custom Transfer Learning with Frozen + Trainable Layers
# Problem: Load a pretrained MobileNetV2 model, freeze base layers, add custom classifier, and fine-tune the top few layers.

from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
from tensorflow.keras.models import Model

base_model = MobileNetV2(weights='imagenet', include_top=False, input_shape=(224,224,3))
for layer in base_model.layers[:-20]:
    layer.trainable = False

x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(128, activation='relu')(x)
output = Dense(2, activation='softmax')(x)

model = Model(inputs=base_model.input, outputs=output)
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9406464/9406464 [==============================] - 7s 1us/step
